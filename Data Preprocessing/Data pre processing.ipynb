# %% [raw]
# 1. Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# 2.Importing the dataset

# %%
raw_df = pd.read_csv("tech_salary_dataset1.csv")

# %%
raw_df
# Out:
#      employee_id first_name  last_name  age      gender  \
# 0      EMP-00001       Emma  Johansson   32      Female
# 1      EMP-00002  Stephanie      Zhang   30      Female
# 2      EMP-00003        Raj      Lopez   32        Male
# 3      EMP-00004     Amelia     Taylor   31      Female
# 4      EMP-00005     Sophia   Gonzalez   42      Female
# ...          ...        ...        ...  ...         ...
# 9995   EMP-09996    Natasha      Silva   38      Female
# 9996   EMP-09997      Jacob       Chen   37        Male
# 9997   EMP-09998        Kai     Muller   31  Non-Binary
# 9998   EMP-09999     Hassan       Chia   32        Male
# 9999   EMP-10000      Tyler      Costa   33        Male
#
#                     location currency           primary_tech_field  \
# 0            Remote (Global)      USD          Backend Development
# 1               Seattle, USA      USD                 QA & Testing
# 2     Amsterdam, Netherlands      EUR          Backend Development
# 3                 London, UK      GBP  Database & Data Engineering
# 4                Boston, USA      USD       Embedded Systems & IoT
# ...                      ...      ...                          ...
# 9995       Sydney, Australia      AUD           Product Management
# 9996             Boston, USA      USD       Full-Stack Development
# 9997        Hyderabad, India      INR       Full-Stack Development
# 9998             Boston, USA      USD            Data Science & ML
# 9999      Seoul, South Korea      KRW         Frontend Development
#
#                       job_title employment_type  ...        company_size  \
# 0             Platform Engineer       Full-time  ...       Small (11-50)
# 1                   QA Engineer       Full-time  ...      Startup (1-10)
# 2                  API Engineer       Full-time  ...  Enterprise (1000+)
# 3            Analytics Engineer       Full-time  ...     Medium (51-200)
# 4             Embedded Engineer       Full-time  ...      Startup (1-10)
# ...                         ...             ...  ...                 ...
# 9995  Associate Product Manager       Full-time  ...    Large (201-1000)
# 9996       Full Stack Developer       Full-time  ...       Small (11-50)
# 9997   Senior Software Engineer       Full-time  ...      Startup (1-10)
# 9998             Data Scientist       Full-time  ...  Enterprise (1000+)
# 9999                UI Engineer       Part-time  ...       Small (11-50)
#
#       annual_salary_usd  has_equity equity_vesting_years vacation_weeks  \
# 0             100290.66       False                    0              3
# 1              92383.12        True                    1              4
# 2             107153.59        True                    4              5
# 3             217074.54        True                    1              2
# 4             152246.34       False                    0              6
# ...                 ...         ...                  ...            ...
# 9995          218700.43        True                    4              3
# 9996          170835.76       False                    0              5
# 9997           25695.15        True                    3              4
# 9998          264531.10       False                    0              4
# 9999          163072.71        True                    4              0
#
#      overtime_hours_per_month months_since_last_promotion  \
# 0                        12.9                          38
# 1                         6.5                          26
# 2                        13.2                           0
# 3                         5.9                         111
# 4                         0.0                          20
# ...                       ...                         ...
# 9995                      7.3                          52
# 9996                      8.4                          58
# 9997                     17.1                           0
# 9998                     14.3                          78
# 9999                     11.1                          11
#
#       num_previous_companies job_satisfaction_score is_actively_looking
# 0                          1                      6               False
# 1                          1                      4               False
# 2                          0                      6                True
# 3                          5                      7               False
# 4                          3                      9               False
# ...                      ...                    ...                 ...
# 9995                       2                      7               False
# 9996                       6                      9               False
# 9997                       0                      8               False
# 9998                       2                      6               False
# 9999                       3                      8               False
#
# [10000 rows x 29 columns]

# %% [markdown]
# 3.Getting basic information about the dataset

# %%
raw_df.shape
# Out:
# (10000, 29)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   employee_id                  10000 non-null  object
#  1   first_name                   10000 non-null  object
#  2   last_name                    10000 non-null  object
#  3   age                          10000 non-null  int64
#  4   gender                       10000 non-null  object
#  5   location                     10000 non-null  object
#  6   currency                     10000 non-null  object
#  7   primary_tech_field           10000 non-null  object
#  8   job_title                    10000 non-null  object
#  9   employment_type              10000 non-null  object
#  10  work_arrangement             10000 non-null  object
#  11  experience_years_total       10000 non-null  float64
#  12  experience_years_in_field    10000 non-null  float64
#  13  education_level              10000 non-null  object
#  14  languages_spoken             10000 non-null  object
#  15  skills                       10000 non-null  object
#  16  primary_skill                10000 non-null  object
#  17  num_skills                   10000 non-null  int64
#  18  certifications               5492 non-null   object
#  19  company_size                 10000 non-null  object
#  20  annual_salary_usd            10000 non-null  float64
#  21  has_equity                   10000 non-null  bool
#  22  equity_vesting_years         10000 non-null  int64
#  23  vacation_weeks               10000 non-null  int64
#  24  overtime_hours_per_month     10000 non-null  float64
#  25  months_since_last_promotion  10000 non-null  int64
#  26  num_previous_companies       10000 non-null  int64
#  27  job_satisfaction_score       10000 non-null  int64
#  28  is_actively_looking          10000 non-null  bool
# dtypes: bool(2), float64(4), int64(7), object(16)
# memory usage: 2.1+ MB

# %%
raw_df['has_equity'] = raw_df['has_equity'].astype(int)
raw_df['is_actively_looking'] = raw_df['is_actively_looking'].astype(int)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   employee_id                  10000 non-null  object
#  1   first_name                   10000 non-null  object
#  2   age                          10000 non-null  int64
#  3   gender                       10000 non-null  object
#  4   location                     10000 non-null  object
#  5   currency                     10000 non-null  object
#  6   job_title                    10000 non-null  object
#  7   employment_type              10000 non-null  object
#  8   work_arrangement             10000 non-null  object
#  9   experience_years_total       10000 non-null  float64
#  10  experience_years_in_field    10000 non-null  float64
#  11  education_level              10000 non-null  object
#  12  languages_spoken             10000 non-null  object
#  13  skills                       10000 non-null  object
#  14  primary_skill                10000 non-null  object
#  15  num_skills                   10000 non-null  int64
#  16  certifications               10000 non-null  object
#  17  company_size                 10000 non-null  object
#  18  annual_salary_usd            10000 non-null  float64
#  19  has_equity                   10000 non-null  int32
#  20  vacation_weeks               10000 non-null  int64
#  21  overtime_hours_per_month     10000 non-null  float64
#  22  months_since_last_promotion  10000 non-null  int64
#  23  num_previous_companies       10000 non-null  int64
#  24  job_satisfaction_score       10000 non-null  int64
#  25  is_actively_looking          10000 non-null  int32
# dtypes: float64(4), int32(2), int64(6), object(14)
# memory usage: 1.9+ MB

# %%
raw_df.describe()
# Out:
#                 age  experience_years_total  experience_years_in_field  \
# count  10000.000000            10000.000000               10000.000000
# mean      31.637600                5.717070                   4.019440
# std        6.856892                3.689415                   2.823968
# min       18.000000                0.500000                   0.500000
# 25%       27.000000                2.800000                   1.800000
# 50%       32.000000                5.500000                   3.600000
# 75%       36.000000                8.200000                   5.700000
# max       58.000000               19.600000                  17.800000
#
#          num_skills  annual_salary_usd    has_equity  vacation_weeks  \
# count  10000.000000       10000.000000  10000.000000    10000.000000
# mean       5.494200      171786.241744      0.499200        3.561300
# std        1.716176       72550.937998      0.500024        1.543464
# min        3.000000       19846.270000      0.000000        0.000000
# 25%        4.000000      121355.045000      0.000000        2.000000
# 50%        5.000000      167055.180000      0.000000        4.000000
# 75%        7.000000      216939.867500      1.000000        5.000000
# max        8.000000      479033.820000      1.000000        6.000000
#
#        overtime_hours_per_month  months_since_last_promotion  \
# count              10000.000000                 10000.000000
# mean                  10.581700                    34.515400
# std                    7.590467                    32.959976
# min                    0.000000                     0.000000
# 25%                    4.500000                     8.000000
# 50%                   10.100000                    26.000000
# 75%                   15.700000                    52.000000
# max                   54.100000                   224.000000
#
#        num_previous_companies  job_satisfaction_score  is_actively_looking
# count            10000.000000            10000.000000         10000.000000
# mean                 1.629600                6.974100             0.200600
# std                  1.539364                2.157428             0.400469
# min                  0.000000                0.000000             0.000000
# 25%                  0.000000                6.000000             0.000000
# 50%                  1.000000                7.000000             0.000000
# 75%                  2.000000                9.000000             0.000000
# max                 10.000000               10.000000             1.000000

# %% [markdown]
# 4.cleaning the Dataset (a) Removing the redundant rows of data

# %%
# Checking the null records
raw_df.isnull().sum()
# Out:
# employee_id                    0
# first_name                     0
# age                            0
# gender                         0
# location                       0
# currency                       0
# job_title                      0
# employment_type                0
# work_arrangement               0
# experience_years_total         0
# experience_years_in_field      0
# education_level                0
# languages_spoken               0
# skills                         0
# primary_skill                  0
# num_skills                     0
# certifications                 0
# company_size                   0
# annual_salary_usd              0
# has_equity                     0
# vacation_weeks                 0
# overtime_hours_per_month       0
# months_since_last_promotion    0
# num_previous_companies         0
# job_satisfaction_score         0
# is_actively_looking            0
# dtype: int64

# %%
raw_df.columns
# Out:
# Index(['employee_id', 'first_name', 'age', 'gender', 'location', 'currency',
#        'job_title', 'employment_type', 'work_arrangement',
#        'experience_years_total', 'experience_years_in_field',
#        'education_level', 'languages_spoken', 'skills', 'primary_skill',
#        'num_skills', 'certifications', 'company_size', 'annual_salary_usd',
#        'has_equity', 'vacation_weeks', 'overtime_hours_per_month',
#        'months_since_last_promotion', 'num_previous_companies',
#        'job_satisfaction_score', 'is_actively_looking'],
#       dtype='object')

# %%
#raw_df.drop(
  #  columns=['last_name', 'primary_tech_field', 'equity_vesting_years'],
  #  inplace=True
#)

# %%
raw_df.fillna({"certifications": 0}, inplace=True)

# %%
raw_df.isnull().sum()
# Out:
# employee_id                    0
# first_name                     0
# age                            0
# gender                         0
# location                       0
# currency                       0
# job_title                      0
# employment_type                0
# work_arrangement               0
# experience_years_total         0
# experience_years_in_field      0
# education_level                0
# languages_spoken               0
# skills                         0
# primary_skill                  0
# num_skills                     0
# certifications                 0
# company_size                   0
# annual_salary_usd              0
# has_equity                     0
# vacation_weeks                 0
# overtime_hours_per_month       0
# months_since_last_promotion    0
# num_previous_companies         0
# job_satisfaction_score         0
# is_actively_looking            0
# dtype: int64

# %%
raw_df['company_size'].value_counts()
# Out:
# company_size
# Enterprise (1000+)    2047
# Medium (51-200)       2021
# Large (201-1000)      2002
# Startup (1-10)        1988
# Small (11-50)         1942
# Name: count, dtype: int64

# %%
raw_df['has_equity'].value_counts()
# Out:
# has_equity
# 0    5008
# 1    4992
# Name: count, dtype: int64

# %%
raw_df[raw_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [employee_id, first_name, age, gender, location, currency, job_title, employment_type, work_arrangement, experience_years_total, experience_years_in_field, education_level, languages_spoken, skills, primary_skill, num_skills, certifications, company_size, annual_salary_usd, has_equity, vacation_weeks, overtime_hours_per_month, months_since_last_promotion, num_previous_companies, job_satisfaction_score, is_actively_looking]
# Index: []
#
# [0 rows x 26 columns]

# %%
def quanQual(raw_df):
    quan=[]
    qual=[]
    for columnName in raw_df.columns:
        #print(columnName)
        if(raw_df[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(raw_df)

# %%
quan
# Out:
# ['age',
#  'experience_years_total',
#  'experience_years_in_field',
#  'num_skills',
#  'annual_salary_usd',
#  'has_equity',
#  'vacation_weeks',
#  'overtime_hours_per_month',
#  'months_since_last_promotion',
#  'num_previous_companies',
#  'job_satisfaction_score',
#  'is_actively_looking']

# %%
raw_df[quan]
# Out:
#       age  experience_years_total  experience_years_in_field  num_skills  \
# 0      32                     7.7                        3.2           3
# 1      30                     3.0                        1.9           8
# 2      32                     0.5                        0.5           8
# 3      31                    14.5                       12.4           4
# 4      42                     7.9                        3.8           4
# ...   ...                     ...                        ...         ...
# 9995   38                     6.2                        3.9           6
# 9996   37                     9.7                        7.0           6
# 9997   31                     0.5                        0.5           5
# 9998   32                     8.7                        8.3           8
# 9999   33                     6.3                        2.5           5
#
#       annual_salary_usd  has_equity  vacation_weeks  overtime_hours_per_month  \
# 0             100290.66           0               3                      12.9
# 1              92383.12           1               4                       6.5
# 2             107153.59           1               5                      13.2
# 3             217074.54           1               2                       5.9
# 4             152246.34           0               6                       0.0
# ...                 ...         ...             ...                       ...
# 9995          218700.43           1               3                       7.3
# 9996          170835.76           0               5                       8.4
# 9997           25695.15           1               4                      17.1
# 9998          264531.10           0               4                      14.3
# 9999          163072.71           1               0                      11.1
#
#       months_since_last_promotion  num_previous_companies  \
# 0                              38                       1
# 1                              26                       1
# 2                               0                       0
# 3                             111                       5
# 4                              20                       3
# ...                           ...                     ...
# 9995                           52                       2
# 9996                           58                       6
# 9997                            0                       0
# 9998                           78                       2
# 9999                           11                       3
#
#       job_satisfaction_score  is_actively_looking
# 0                          6                    0
# 1                          4                    0
# 2                          6                    1
# 3                          7                    0
# 4                          9                    0
# ...                      ...                  ...
# 9995                       7                    0
# 9996                       9                    0
# 9997                       8                    0
# 9998                       6                    0
# 9999                       8                    0
#
# [10000 rows x 12 columns]

# %%
raw_df[qual]
# Out:
#      employee_id first_name      gender                location currency  \
# 0      EMP-00001       Emma      Female         Remote (Global)      USD
# 1      EMP-00002  Stephanie      Female            Seattle, USA      USD
# 2      EMP-00003        Raj        Male  Amsterdam, Netherlands      EUR
# 3      EMP-00004     Amelia      Female              London, UK      GBP
# 4      EMP-00005     Sophia      Female             Boston, USA      USD
# ...          ...        ...         ...                     ...      ...
# 9995   EMP-09996    Natasha      Female       Sydney, Australia      AUD
# 9996   EMP-09997      Jacob        Male             Boston, USA      USD
# 9997   EMP-09998        Kai  Non-Binary        Hyderabad, India      INR
# 9998   EMP-09999     Hassan        Male             Boston, USA      USD
# 9999   EMP-10000      Tyler        Male      Seoul, South Korea      KRW
#
#                       job_title employment_type work_arrangement  \
# 0             Platform Engineer       Full-time           Remote
# 1                   QA Engineer       Full-time          On-site
# 2                  API Engineer       Full-time           Remote
# 3            Analytics Engineer       Full-time           Hybrid
# 4             Embedded Engineer       Full-time     Fully Remote
# ...                         ...             ...              ...
# 9995  Associate Product Manager       Full-time     Fully Remote
# 9996       Full Stack Developer       Full-time          On-site
# 9997   Senior Software Engineer       Full-time           Remote
# 9998             Data Scientist       Full-time           Hybrid
# 9999                UI Engineer       Part-time     Fully Remote
#
#          education_level                 languages_spoken  \
# 0     Associate's Degree                          English
# 1               Bootcamp                  English; Telugu
# 2      Bachelor's Degree  English; German; Spanish; Dutch
# 3               Bootcamp        English; German; Mandarin
# 4               Bootcamp                  English; Telugu
# ...                  ...                              ...
# 9995            Bootcamp                          English
# 9996            Bootcamp                          English
# 9997   Bachelor's Degree                          English
# 9998            Bootcamp                 English; Bengali
# 9999     Master's Degree                   English; Tamil
#
#                                                  skills primary_skill  \
# 0                              Spring Boot; PHP; Python   Spring Boot
# 1     PyTest; API Testing; Cypress; JUnit; Postman; ...        PyTest
# 2     PHP; Express.js; Java; Rust; Spring Boot; C#; ...           PHP
# 3              Snowflake; Elasticsearch; Cassandra; dbt     Snowflake
# 4                 RTOS; ARM; PCB Design; Embedded Linux          RTOS
# ...                                                 ...           ...
# 9995  Jira; Confluence; Wireframing; SQL; Agile; Roa...          Jira
# 9996  GraphQL; Python; Vue.js; REST APIs; Docker; Mo...       GraphQL
# 9997   TypeScript; Redis; REST APIs; PostgreSQL; Python    TypeScript
# 9998  OpenCV; SQL; Keras; Python; R; PyTorch; scikit...        OpenCV
# 9999     HTML/CSS; TypeScript; Vue.js; Webpack; GraphQL      HTML/CSS
#
#                                          certifications        company_size
# 0                                                     0       Small (11-50)
# 1                                                     0      Startup (1-10)
# 2                     AWS Certified Solutions Architect  Enterprise (1000+)
# 3                            Linux Foundation Certified     Medium (51-200)
# 4                                                     0      Startup (1-10)
# ...                                                 ...                 ...
# 9995                                                  0    Large (201-1000)
# 9996  Certified Scrum Master; Azure Solutions Architect       Small (11-50)
# 9997                                                  0      Startup (1-10)
# 9998                                     Kubernetes CKA  Enterprise (1000+)
# 9999                                                  0       Small (11-50)
#
# [10000 rows x 14 columns]

# %%
qual
# Out:
# ['employee_id',
#  'first_name',
#  'gender',
#  'location',
#  'currency',
#  'job_title',
#  'employment_type',
#  'work_arrangement',
#  'education_level',
#  'languages_spoken',
#  'skills',
#  'primary_skill',
#  'certifications',
#  'company_size']

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=10, random_state=0)
imp.fit(raw_df[quan])
df = imp.fit_transform(raw_df[quan])

# %%
df = pd.DataFrame(df,columns = quan)

# %%
df
# Out:
#        age  experience_years_total  experience_years_in_field  num_skills  \
# 0     32.0                     7.7                        3.2         3.0
# 1     30.0                     3.0                        1.9         8.0
# 2     32.0                     0.5                        0.5         8.0
# 3     31.0                    14.5                       12.4         4.0
# 4     42.0                     7.9                        3.8         4.0
# ...    ...                     ...                        ...         ...
# 9995  38.0                     6.2                        3.9         6.0
# 9996  37.0                     9.7                        7.0         6.0
# 9997  31.0                     0.5                        0.5         5.0
# 9998  32.0                     8.7                        8.3         8.0
# 9999  33.0                     6.3                        2.5         5.0
#
#       annual_salary_usd  has_equity  vacation_weeks  overtime_hours_per_month  \
# 0             100290.66         0.0             3.0                      12.9
# 1              92383.12         1.0             4.0                       6.5
# 2             107153.59         1.0             5.0                      13.2
# 3             217074.54         1.0             2.0                       5.9
# 4             152246.34         0.0             6.0                       0.0
# ...                 ...         ...             ...                       ...
# 9995          218700.43         1.0             3.0                       7.3
# 9996          170835.76         0.0             5.0                       8.4
# 9997           25695.15         1.0             4.0                      17.1
# 9998          264531.10         0.0             4.0                      14.3
# 9999          163072.71         1.0             0.0                      11.1
#
#       months_since_last_promotion  num_previous_companies  \
# 0                            38.0                     1.0
# 1                            26.0                     1.0
# 2                             0.0                     0.0
# 3                           111.0                     5.0
# 4                            20.0                     3.0
# ...                           ...                     ...
# 9995                         52.0                     2.0
# 9996                         58.0                     6.0
# 9997                          0.0                     0.0
# 9998                         78.0                     2.0
# 9999                         11.0                     3.0
#
#       job_satisfaction_score  is_actively_looking
# 0                        6.0                  0.0
# 1                        4.0                  0.0
# 2                        6.0                  1.0
# 3                        7.0                  0.0
# 4                        9.0                  0.0
# ...                      ...                  ...
# 9995                     7.0                  0.0
# 9996                     9.0                  0.0
# 9997                     8.0                  0.0
# 9998                     6.0                  0.0
# 9999                     8.0                  0.0
#
# [10000 rows x 12 columns]

# %%
raw_df.isna().sum()
# Out:
# employee_id                    0
# first_name                     0
# age                            0
# gender                         0
# location                       0
# currency                       0
# job_title                      0
# employment_type                0
# work_arrangement               0
# experience_years_total         0
# experience_years_in_field      0
# education_level                0
# languages_spoken               0
# skills                         0
# primary_skill                  0
# num_skills                     0
# certifications                 0
# company_size                   0
# annual_salary_usd              0
# has_equity                     0
# vacation_weeks                 0
# overtime_hours_per_month       0
# months_since_last_promotion    0
# num_previous_companies         0
# job_satisfaction_score         0
# is_actively_looking            0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp_cat = SimpleImputer(strategy="most_frequent")
cate=raw_df[qual]
cate = imp_cat.fit_transform(raw_df[qual])

# %%
cate = pd.DataFrame(cate,columns = qual)

# %%
cate
# Out:
#      employee_id first_name      gender                location currency  \
# 0      EMP-00001       Emma      Female         Remote (Global)      USD
# 1      EMP-00002  Stephanie      Female            Seattle, USA      USD
# 2      EMP-00003        Raj        Male  Amsterdam, Netherlands      EUR
# 3      EMP-00004     Amelia      Female              London, UK      GBP
# 4      EMP-00005     Sophia      Female             Boston, USA      USD
# ...          ...        ...         ...                     ...      ...
# 9995   EMP-09996    Natasha      Female       Sydney, Australia      AUD
# 9996   EMP-09997      Jacob        Male             Boston, USA      USD
# 9997   EMP-09998        Kai  Non-Binary        Hyderabad, India      INR
# 9998   EMP-09999     Hassan        Male             Boston, USA      USD
# 9999   EMP-10000      Tyler        Male      Seoul, South Korea      KRW
#
#                       job_title employment_type work_arrangement  \
# 0             Platform Engineer       Full-time           Remote
# 1                   QA Engineer       Full-time          On-site
# 2                  API Engineer       Full-time           Remote
# 3            Analytics Engineer       Full-time           Hybrid
# 4             Embedded Engineer       Full-time     Fully Remote
# ...                         ...             ...              ...
# 9995  Associate Product Manager       Full-time     Fully Remote
# 9996       Full Stack Developer       Full-time          On-site
# 9997   Senior Software Engineer       Full-time           Remote
# 9998             Data Scientist       Full-time           Hybrid
# 9999                UI Engineer       Part-time     Fully Remote
#
#          education_level                 languages_spoken  \
# 0     Associate's Degree                          English
# 1               Bootcamp                  English; Telugu
# 2      Bachelor's Degree  English; German; Spanish; Dutch
# 3               Bootcamp        English; German; Mandarin
# 4               Bootcamp                  English; Telugu
# ...                  ...                              ...
# 9995            Bootcamp                          English
# 9996            Bootcamp                          English
# 9997   Bachelor's Degree                          English
# 9998            Bootcamp                 English; Bengali
# 9999     Master's Degree                   English; Tamil
#
#                                                  skills primary_skill  \
# 0                              Spring Boot; PHP; Python   Spring Boot
# 1     PyTest; API Testing; Cypress; JUnit; Postman; ...        PyTest
# 2     PHP; Express.js; Java; Rust; Spring Boot; C#; ...           PHP
# 3              Snowflake; Elasticsearch; Cassandra; dbt     Snowflake
# 4                 RTOS; ARM; PCB Design; Embedded Linux          RTOS
# ...                                                 ...           ...
# 9995  Jira; Confluence; Wireframing; SQL; Agile; Roa...          Jira
# 9996  GraphQL; Python; Vue.js; REST APIs; Docker; Mo...       GraphQL
# 9997   TypeScript; Redis; REST APIs; PostgreSQL; Python    TypeScript
# 9998  OpenCV; SQL; Keras; Python; R; PyTorch; scikit...        OpenCV
# 9999     HTML/CSS; TypeScript; Vue.js; Webpack; GraphQL      HTML/CSS
#
#                                          certifications        company_size
# 0                                                     0       Small (11-50)
# 1                                                     0      Startup (1-10)
# 2                     AWS Certified Solutions Architect  Enterprise (1000+)
# 3                            Linux Foundation Certified     Medium (51-200)
# 4                                                     0      Startup (1-10)
# ...                                                 ...                 ...
# 9995                                                  0    Large (201-1000)
# 9996  Certified Scrum Master; Azure Solutions Architect       Small (11-50)
# 9997                                                  0      Startup (1-10)
# 9998                                     Kubernetes CKA  Enterprise (1000+)
# 9999                                                  0       Small (11-50)
#
# [10000 rows x 14 columns]

# %%
two=[df,cate]

# %%
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#        age  experience_years_total  experience_years_in_field  num_skills  \
# 0     32.0                     7.7                        3.2         3.0
# 1     30.0                     3.0                        1.9         8.0
# 2     32.0                     0.5                        0.5         8.0
# 3     31.0                    14.5                       12.4         4.0
# 4     42.0                     7.9                        3.8         4.0
# ...    ...                     ...                        ...         ...
# 9995  38.0                     6.2                        3.9         6.0
# 9996  37.0                     9.7                        7.0         6.0
# 9997  31.0                     0.5                        0.5         5.0
# 9998  32.0                     8.7                        8.3         8.0
# 9999  33.0                     6.3                        2.5         5.0
#
#       annual_salary_usd  has_equity  vacation_weeks  overtime_hours_per_month  \
# 0             100290.66         0.0             3.0                      12.9
# 1              92383.12         1.0             4.0                       6.5
# 2             107153.59         1.0             5.0                      13.2
# 3             217074.54         1.0             2.0                       5.9
# 4             152246.34         0.0             6.0                       0.0
# ...                 ...         ...             ...                       ...
# 9995          218700.43         1.0             3.0                       7.3
# 9996          170835.76         0.0             5.0                       8.4
# 9997           25695.15         1.0             4.0                      17.1
# 9998          264531.10         0.0             4.0                      14.3
# 9999          163072.71         1.0             0.0                      11.1
#
#       months_since_last_promotion  num_previous_companies  ...  currency  \
# 0                            38.0                     1.0  ...       USD
# 1                            26.0                     1.0  ...       USD
# 2                             0.0                     0.0  ...       EUR
# 3                           111.0                     5.0  ...       GBP
# 4                            20.0                     3.0  ...       USD
# ...                           ...                     ...  ...       ...
# 9995                         52.0                     2.0  ...       AUD
# 9996                         58.0                     6.0  ...       USD
# 9997                          0.0                     0.0  ...       INR
# 9998                         78.0                     2.0  ...       USD
# 9999                         11.0                     3.0  ...       KRW
#
#                       job_title employment_type work_arrangement  \
# 0             Platform Engineer       Full-time           Remote
# 1                   QA Engineer       Full-time          On-site
# 2                  API Engineer       Full-time           Remote
# 3            Analytics Engineer       Full-time           Hybrid
# 4             Embedded Engineer       Full-time     Fully Remote
# ...                         ...             ...              ...
# 9995  Associate Product Manager       Full-time     Fully Remote
# 9996       Full Stack Developer       Full-time          On-site
# 9997   Senior Software Engineer       Full-time           Remote
# 9998             Data Scientist       Full-time           Hybrid
# 9999                UI Engineer       Part-time     Fully Remote
#
#          education_level                 languages_spoken  \
# 0     Associate's Degree                          English
# 1               Bootcamp                  English; Telugu
# 2      Bachelor's Degree  English; German; Spanish; Dutch
# 3               Bootcamp        English; German; Mandarin
# 4               Bootcamp                  English; Telugu
# ...                  ...                              ...
# 9995            Bootcamp                          English
# 9996            Bootcamp                          English
# 9997   Bachelor's Degree                          English
# 9998            Bootcamp                 English; Bengali
# 9999     Master's Degree                   English; Tamil
#
#                                                  skills primary_skill  \
# 0                              Spring Boot; PHP; Python   Spring Boot
# 1     PyTest; API Testing; Cypress; JUnit; Postman; ...        PyTest
# 2     PHP; Express.js; Java; Rust; Spring Boot; C#; ...           PHP
# 3              Snowflake; Elasticsearch; Cassandra; dbt     Snowflake
# 4                 RTOS; ARM; PCB Design; Embedded Linux          RTOS
# ...                                                 ...           ...
# 9995  Jira; Confluence; Wireframing; SQL; Agile; Roa...          Jira
# 9996  GraphQL; Python; Vue.js; REST APIs; Docker; Mo...       GraphQL
# 9997   TypeScript; Redis; REST APIs; PostgreSQL; Python    TypeScript
# 9998  OpenCV; SQL; Keras; Python; R; PyTorch; scikit...        OpenCV
# 9999     HTML/CSS; TypeScript; Vue.js; Webpack; GraphQL      HTML/CSS
#
#                                          certifications        company_size
# 0                                                     0       Small (11-50)
# 1                                                     0      Startup (1-10)
# 2                     AWS Certified Solutions Architect  Enterprise (1000+)
# 3                            Linux Foundation Certified     Medium (51-200)
# 4                                                     0      Startup (1-10)
# ...                                                 ...                 ...
# 9995                                                  0    Large (201-1000)
# 9996  Certified Scrum Master; Azure Solutions Architect       Small (11-50)
# 9997                                                  0      Startup (1-10)
# 9998                                     Kubernetes CKA  Enterprise (1000+)
# 9999                                                  0       Small (11-50)
#
# [10000 rows x 26 columns]

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def Bivariate(preprocessed,quan):
        descriptive=pd.DataFrame(index=["Mean","Median","Mode","25%","50%","75%","99%","100%","IQR","1.5rule","Lesser","Greater","Min","Max","Skew","Kurtosis","Var","SD"],columns=quan)
        for columnName in quan:
            descriptive[columnName]["Mean"]=preprocessed[columnName].mean()
            descriptive[columnName]["Median"]=preprocessed[columnName].median()
            descriptive[columnName]["Mode"]=preprocessed[columnName].mode()[0]
            descriptive[columnName]["25%"]=preprocessed.describe()[columnName]["25%"]
            descriptive[columnName]["50%"]=preprocessed.describe()[columnName]["50%"]
            descriptive[columnName]["75%"]=preprocessed.describe()[columnName]["75%"]
            descriptive[columnName]["99%"]=np.percentile(preprocessed[columnName],99)
            descriptive[columnName]["100%"]=preprocessed.describe()[columnName]["max"]
            descriptive[columnName]["IQR"]=descriptive[columnName]["75%"]-descriptive[columnName]["25%"]
            descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
            descriptive[columnName]["Lesser"]=descriptive[columnName]["25%"]-descriptive[columnName]["1.5rule"]
            descriptive[columnName]["Greater"]=descriptive[columnName]["75%"]+descriptive[columnName]["1.5rule"]
            descriptive[columnName]["Min"]=preprocessed[columnName].min()
            descriptive[columnName]["Max"]=preprocessed[columnName].max()
            descriptive[columnName]["Skew"]=preprocessed[columnName].skew()
            descriptive[columnName]["Kurtosis"]=preprocessed[columnName].kurtosis()
            descriptive[columnName]["Var"]=preprocessed[columnName].var()
            descriptive[columnName]["SD"]=preprocessed[columnName].std()
        return descriptive

# %%
 Bivariate(preprocessed,quan)
# Out:
#                 age experience_years_total experience_years_in_field  \
# Mean        31.6376                5.71707                   4.01944
# Median         32.0                    5.5                       3.6
# Mode           33.0                    0.5                       0.5
# 25%            27.0                    2.8                       1.8
# 50%            32.0                    5.5                       3.6
# 75%            36.0                    8.2                       5.7
# 99%            48.0                   15.2                    12.101
# 100%           58.0                   19.6                      17.8
# IQR             9.0                    5.4                       3.9
# 1.5rule        13.5                    8.1                      5.85
# Lesser         13.5                   -5.3                     -4.05
# Greater        49.5                   16.3                     11.55
# Min            18.0                    0.5                       0.5
# Max            58.0                   19.6                      17.8
# Skew       0.148569                0.43369                  0.857686
# Kurtosis  -0.275062              -0.340405                  0.674418
# Var       47.016968              13.611785                  7.974796
# SD         6.856892               3.689415                  2.823968
#
#          num_skills  annual_salary_usd has_equity vacation_weeks  \
# Mean         5.4942      171786.241744     0.4992         3.5613
# Median          5.0          167055.18        0.0            4.0
# Mode            4.0          198390.48        0.0            4.0
# 25%             4.0         121355.045        0.0            2.0
# 50%             5.0          167055.18        0.0            4.0
# 75%             7.0        216939.8675        1.0            5.0
# 99%             8.0        365745.6973        1.0            6.0
# 100%            8.0          479033.82        1.0            6.0
# IQR             3.0         95584.8225        1.0            3.0
# 1.5rule         4.5       143377.23375        1.5            4.5
# Lesser         -0.5       -22022.18875       -1.5           -2.5
# Greater        11.5       360317.10125        2.5            9.5
# Min             3.0           19846.27        0.0            0.0
# Max             8.0          479033.82        1.0            6.0
# Skew       0.009438           0.448127     0.0032      -0.487304
# Kurtosis  -1.280588           0.232242   -2.00039      -0.534389
# Var        2.945261  5263638604.410822   0.250024       2.382281
# SD         1.716176       72550.937998   0.500024       1.543464
#
#          overtime_hours_per_month months_since_last_promotion  \
# Mean                      10.5817                     34.5154
# Median                       10.1                        26.0
# Mode                          0.0                         0.0
# 25%                           4.5                         8.0
# 50%                          10.1                        26.0
# 75%                          15.7                        52.0
# 99%                          29.9                       136.0
# 100%                         54.1                       224.0
# IQR                          11.2                        44.0
# 1.5rule                      16.8                        66.0
# Lesser                      -12.3                       -58.0
# Greater                      32.5                       118.0
# Min                           0.0                         0.0
# Max                          54.1                       224.0
# Skew                     0.504883                    1.232485
# Kurtosis                -0.077773                    1.502684
# Var                     57.615195                 1086.359999
# SD                       7.590467                   32.959976
#
#          num_previous_companies job_satisfaction_score is_actively_looking
# Mean                     1.6296                 6.9741              0.2006
# Median                      1.0                    7.0                 0.0
# Mode                        1.0                    7.0                 0.0
# 25%                         0.0                    6.0                 0.0
# 50%                         1.0                    7.0                 0.0
# 75%                         2.0                    9.0                 0.0
# 99%                         6.0                   10.0                 1.0
# 100%                       10.0                   10.0                 1.0
# IQR                         2.0                    3.0                 0.0
# 1.5rule                     3.0                    4.5                 0.0
# Lesser                     -3.0                    1.5                 0.0
# Greater                     5.0                   13.5                 0.0
# Min                         0.0                    0.0                 0.0
# Max                        10.0                   10.0                 1.0
# Skew                   1.154458              -0.708702            1.495545
# Kurtosis               1.542373               0.075104            0.236701
# Var                    2.369641               4.654495            0.160376
# SD                     1.539364               2.157428            0.400469
